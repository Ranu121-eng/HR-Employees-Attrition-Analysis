# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("Cleaned_Sheet.csv")

# %%
df.head()
# Out:
#    Age Age Group Attrition     BusinessTravel  DailyRate  \
# 0   41     36-45       Yes      Travel_Rarely       1102
# 1   49     46-55        No  Travel_Frequently        279
# 2   37     36-45       Yes      Travel_Rarely       1373
# 3   33     26-35        No  Travel_Frequently       1392
# 4   27     26-35        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  StandardHours  StockOptionLevel TotalWorkingYears  \
# 0              1  ...             80                 0                 8
# 1              1  ...             80                 1                10
# 2              1  ...             80                 0                 7
# 3              1  ...             80                 0                 8
# 4              1  ...             80                 1                 6
#
#    TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  Year Group  \
# 0                      0                1               6  6-10 Years
# 1                      3                3              10  6-10 Years
# 2                      3                3               0   0-2 Years
# 3                      3                3               8  6-10 Years
# 4                      3                3               2   0-2 Years
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                       0                     5
# 1                   7                       1                     7
# 2                   0                       0                     0
# 3                   7                       3                     0
# 4                   2                       2                     2
#
# [5 rows x 38 columns]

# %%
df.tail()
# Out:
#       Age Age Group Attrition     BusinessTravel  DailyRate  \
# 1465   36     36-45        No  Travel_Frequently        884
# 1466   39     36-45        No      Travel_Rarely        613
# 1467   27     26-35        No      Travel_Rarely        155
# 1468   49     46-55        No  Travel_Frequently       1023
# 1469   34     26-35        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1465  Research & Development                23          2        Medical
# 1466  Research & Development                 6          1        Medical
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  StandardHours  StockOptionLevel TotalWorkingYears  \
# 1465              1  ...             80                 1                17
# 1466              1  ...             80                 1                 9
# 1467              1  ...             80                 1                 6
# 1468              1  ...             80                 0                17
# 1469              1  ...             80                 0                 6
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  Year Group  \
# 1465                      3                3               5   3-5 Years
# 1466                      5                3               7  6-10 Years
# 1467                      0                3               6  6-10 Years
# 1468                      3                2               9  6-10 Years
# 1469                      3                4               4   3-5 Years
#
#       YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 1465                   2                       0                     3
# 1466                   7                       1                     7
# 1467                   2                       0                     3
# 1468                   6                       0                     8
# 1469                   3                       1                     2
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Age Group                 1470 non-null   object
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1470 non-null   int64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1470 non-null   object
#  13  HourlyRate                1470 non-null   int64
#  14  JobInvolvement            1470 non-null   int64
#  15  JobLevel                  1470 non-null   int64
#  16  JobRole                   1470 non-null   object
#  17  JobSatisfaction           1470 non-null   int64
#  18  MaritalStatus             1470 non-null   object
#  19  MonthlyIncome             1470 non-null   int64
#  20  Income Group              1470 non-null   object
#  21  MonthlyRate               1470 non-null   int64
#  22  NumCompaniesWorked        1470 non-null   int64
#  23  Over18                    1470 non-null   object
#  24  OverTime                  1470 non-null   object
#  25  PercentSalaryHike         1470 non-null   int64
#  26  PerformanceRating         1470 non-null   int64
#  27  RelationshipSatisfaction  1470 non-null   int64
#  28  StandardHours             1470 non-null   int64
#  29  StockOptionLevel          1470 non-null   int64
#  30  TotalWorkingYears         1470 non-null   int64
#  31  TrainingTimesLastYear     1470 non-null   int64
#  32  WorkLifeBalance           1470 non-null   int64
#  33  YearsAtCompany            1470 non-null   int64
#  34  Year Group                1470 non-null   object
#  35  YearsInCurrentRole        1470 non-null   int64
#  36  YearsSinceLastPromotion   1470 non-null   int64
#  37  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(12)
# memory usage: 436.5+ KB

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# 25%        491.250000                 2.000000    48.000000        2.000000
# 50%       1020.500000                 3.000000    66.000000        3.000000
# 75%       1555.750000                 4.000000    83.750000        3.000000
# max       2068.000000                 4.000000   100.000000        4.000000
#
#           JobLevel  ...  RelationshipSatisfaction  StandardHours  \
# count  1470.000000  ...               1470.000000         1470.0
# mean      2.063946  ...                  2.712245           80.0
# std       1.106940  ...                  1.081209            0.0
# min       1.000000  ...                  1.000000           80.0
# 25%       1.000000  ...                  2.000000           80.0
# 50%       2.000000  ...                  3.000000           80.0
# 75%       3.000000  ...                  4.000000           80.0
# max       5.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Age Group', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'Income Group',
#        'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'Year Group', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         Age  Age Group  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False      False           False      False       False
# 1     False      False      False           False      False       False
# 2     False      False      False           False      False       False
# 3     False      False      False           False      False       False
# 4     False      False      False           False      False       False
# ...     ...        ...        ...             ...        ...         ...
# 1465  False      False      False           False      False       False
# 1466  False      False      False           False      False       False
# 1467  False      False      False           False      False       False
# 1468  False      False      False           False      False       False
# 1469  False      False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                False      False           False          False  ...
# 1                False      False           False          False  ...
# 2                False      False           False          False  ...
# 3                False      False           False          False  ...
# 4                False      False           False          False  ...
# ...                ...        ...             ...            ...  ...
# 1465             False      False           False          False  ...
# 1466             False      False           False          False  ...
# 1467             False      False           False          False  ...
# 1468             False      False           False          False  ...
# 1469             False      False           False          False  ...
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# 0             False             False              False
# 1             False             False              False
# 2             False             False              False
# 3             False             False              False
# 4             False             False              False
# ...             ...               ...                ...
# 1465          False             False              False
# 1466          False             False              False
# 1467          False             False              False
# 1468          False             False              False
# 1469          False             False              False
#
#       TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  Year Group  \
# 0                     False            False           False       False
# 1                     False            False           False       False
# 2                     False            False           False       False
# 3                     False            False           False       False
# 4                     False            False           False       False
# ...                     ...              ...             ...         ...
# 1465                  False            False           False       False
# 1466                  False            False           False       False
# 1467                  False            False           False       False
# 1468                  False            False           False       False
# 1469                  False            False           False       False
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  False                    False                 False
# 1                  False                    False                 False
# 2                  False                    False                 False
# 3                  False                    False                 False
# 4                  False                    False                 False
# ...                  ...                      ...                   ...
# 1465               False                    False                 False
# 1466               False                    False                 False
# 1467               False                    False                 False
# 1468               False                    False                 False
# 1469               False                    False                 False
#
# [1470 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# Age                         0
# Age Group                   0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# Income Group                0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# Year Group                  0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Attrition"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df["Age"].max()
# Out:
# 60

# %%
df["Age"].min()
# Out:
# 18

# %%
df["MonthlyIncome"].min()
# Out:
# 1009

# %%
df["MonthlyIncome"].max()
# Out:
# 19999

# %%
df["YearsAtCompany"].min()
# Out:
# 0

# %%
df["YearsAtCompany"].max()
# Out:
# 40

# %% [markdown]
# ## Attrition

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %% [markdown]
# ### Calculate total attrition

# %%
total_employees = len(df)
employee_left = (df["Attrition"] == "Yes").sum()
attrition_rate = employee_left / total_employees * 100
print("Total Employees:", total_employees)
print("Employees Left:", employee_left)
print("Attrition Rate:", round(attrition_rate, 2), "%")
# Out:
# Total Employees: 1470
# Employees Left: 237
# Attrition Rate: 16.12 %

# %% [markdown]
# ### Average age

# %%
avg_age = df["Age"].mean().round(2)
print("Average Age:", avg_age)
# Out:
# Average Age: 36.92

# %% [markdown]
# ### Average year

# %%
avg_years = df["YearsAtCompany"].mean().round(2)
print("Average Years:", avg_years)
# Out:
# Average Years: 7.01

# %% [markdown]
# ### Active employees

# %%
active_employees = (df["Attrition"] == "No").sum()
print("Active Employees:",active_employees)
# Out:
# Active Employees: 1233

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Department wise Attrition

# %%
department_attrition = (
    df.groupby("Department")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)

print(department_attrition)
# Out:
# Department
# Human Resources           19.047619
# Research & Development    13.839750
# Sales                     20.627803
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(4, 4))

plt.bar(
    department_attrition.index,
    department_attrition.values
)

plt.title("Department vs Attrition")
plt.xlabel("Department")
plt.ylabel("Attrition Rate (%)")

plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Salary wise Attrition

# %%
salary_attrition = df.groupby("Attrition")["MonthlyIncome"].mean()
print(salary_attrition)
# Out:
# Attrition
# No     6832.739659
# Yes    4787.092827
# Name: MonthlyIncome, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    salary_attrition.index,
    salary_attrition.values
)
plt.title("Salary vs Attrition")
plt.xlabel("Attrition")
plt.ylabel("Average Monthly Income")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Age wise Attrition

# %%
age_attrition = df.groupby("Attrition")["Age"].mean()
print(age_attrition)
# Out:
# Attrition
# No     37.561233
# Yes    33.607595
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    age_attrition.index,
    age_attrition.values
)
plt.title("Age vs Attrition")
plt.xlabel("Attrition")
plt.ylabel("Average Age")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Gender wise Attrition

# %%
gender_attrition = (
    df.groupby("Gender")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)
print(gender_attrition)
# Out:
# Gender
# Female    14.795918
# Male      17.006803
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    gender_attrition.index,
    gender_attrition.values
)
plt.title("Gender vs Attrition")
plt.xlabel("Gender")
plt.ylabel("Attrition Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### OverTime wise Attrition

# %%
overtime_attrition = (
    df.groupby("OverTime")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)
print(overtime_attrition)
# Out:
# OverTime
# No     10.436433
# Yes    30.528846
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    overtime_attrition.index,
    overtime_attrition.values
)
plt.title("OverTime vs Attrition")
plt.xlabel("OverTime")
plt.ylabel("Attrition Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distance from home wise Atttrition

# %%
distance_attrition = (
    df.groupby("Attrition")["DistanceFromHome"].mean()
)
print(distance_attrition)
# Out:
# Attrition
# No      8.915653
# Yes    10.632911
# Name: DistanceFromHome, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    distance_attrition.index,
    distance_attrition.values
)
plt.title("Distance From Home vs Attrition")
plt.xlabel("Attrition")
plt.ylabel("Average Distance From Home")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Promotion wise Attrition

# %%
promotion_attrition = (
    df.groupby("Attrition")["YearsSinceLastPromotion"].mean()
)
print(promotion_attrition)
# Out:
# Attrition
# No     2.234388
# Yes    1.945148
# Name: YearsSinceLastPromotion, dtype: float64

# %%
plt.figure(figsize=(3, 4))
plt.bar(
    promotion_attrition.index,
    promotion_attrition.values
)
plt.title("Promotion vs Attrition")
plt.xlabel("Attrition")
plt.ylabel("Average Years Since Last Promotion")
plt.tight_layout()
plt.show()

# %%
satisfaction_attrition = (
    df.groupby("JobSatisfaction")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)
print(satisfaction_attrition)
# Out:
# JobSatisfaction
# 1    22.837370
# 2    16.428571
# 3    16.515837
# 4    11.328976
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(4, 4))
plt.bar(
    satisfaction_attrition.index.astype(str),
    satisfaction_attrition.values
)
plt.title("Job Satisfaction vs Attrition")
plt.xlabel("Job Satisfaction Level")
plt.ylabel("Attrition Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Education wise Attrition

# %%
education_attrition = (
    df.groupby("Education")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)
print(education_attrition)
# Out:
# Education
# 1    18.235294
# 2    15.602837
# 3    17.307692
# 4    14.572864
# 5    10.416667
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(4, 4))
plt.bar(
    education_attrition.index.astype(str),
    education_attrition.values
)
plt.title("Education Level vs Attrition")
plt.xlabel("Education Level")
plt.ylabel("Attrition Rate (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Business Travel wise Attrition

# %%
travel_attrition = (
    df.groupby("BusinessTravel")["Attrition"]
      .apply(lambda x: (x == "Yes").mean() * 100)
)
print(travel_attrition)
# Out:
# BusinessTravel
# Non-Travel            8.000000
# Travel_Frequently    24.909747
# Travel_Rarely        14.956855
# Name: Attrition, dtype: float64

# %%
plt.figure(figsize=(4, 4))
plt.bar(
    travel_attrition.index,
    travel_attrition.values
)
plt.title("Business Travel vs Attrition")
plt.xlabel("Business Travel")
plt.ylabel("Attrition Rate (%)")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
df.to_csv("HR_Employees_Attrition.csv", index=False)
